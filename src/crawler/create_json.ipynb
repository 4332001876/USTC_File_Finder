# %%
'''
json包含以下几项内容：
  - url: 网站地址
  - encoding: 网站编码
  - title: 网站标题
  - dtype: 该列表文件类型
  - dtype2: 该列表文件类型的子类型
  - flip: 该网站是否可以翻页
  - html_locator: 该网站对应的文件列表html定位器
  - info_locator: 该网站文件列表下每个文件的信息定位器

在定位器部分，示例：
  - html_locator = [
    {'method': 'find', 'args': 'div', 'kwargs': {'class_': 'r-box'}},
    {'method': 'find', 'args': 'ul'},
    {'method': 'find_all', 'args': 'li'}
                   ]
    对应的操作是：
    bs_result = bs.find('div', class_='r-box')
    bs_result = bs_result.find('ul')
    bs_result = bs_result.find_all('li')

   - info_locator = [
    {'info': 'title', 'method': 'find', 'args': 'a', 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': 'time', 'args2': 'text'},
                    ]
    对应的操作是：
    result[i]['title'] = bs_result[i].find('a').text.strip()
    result[i]['url'] = urljoin(url, bs_result[i].find('a')['href'])
    result[i]['time'] = bs_result[i].find('time').text.strip()
'''
# Out:
# "\njson包含以下几项内容：\n  - url: 网站地址\n  - title: 网站标题\n  - dtype: 该列表文件类型\n  - dtype2: 该列表文件类型的子类型\n  - flip: 该网站是否可以翻页\n  - html_locator: 该网站对应的文件列表html定位器\n  - info_locator: 该网站文件列表下每个文件的信息定位器\n\n在定位器部分，示例：\n  - html_locator = [\n    {'method': 'find', 'args': 'div', 'kwargs': {'class_': 'r-box'}},\n    {'method': 'find', 'args': 'ul'},\n    {'method': 'find_all', 'args': 'li'}\n                   ]\n    对应的操作是：\n    bs_result = bs.find('div', class_='r-box')\n    bs_result = bs_result.find('ul')\n    bs_result = bs_result.find_all('li')\n\n   - info_locator = [\n    {'info': 'title', 'method': 'find', 'args': 'a', 'args2': 'text'},\n    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},\n    {'info': 'time', 'method': 'find', 'args': 'time', 'args2': 'text'},\n                    ]\n    对应的操作是：\n    result[i]['title'] = bs_result[i].find('a').text.strip()\n    result[i]['url'] = urljoin(url, bs_result[i].find('a')['href'])\n    result[i]['time'] = bs_result[i].find('time'
# ...

# %%
import json

def create_json(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator):
    data = {
        'url': url,
        'encoding': encoding,
        'title': title,
        'dtype': dtype,
        'dtype2': dtype2,
        'flip': flip,
        'html_locator': html_locator,
        'info_locator': info_locator
    }


    data_list = []

    data_list.append(data)

    with open('data.json', 'w', encoding='utf-8') as f:
        json.dump(data_list, f, ensure_ascii=False, indent=4)

def add_data(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator):
    data = {
        'url': url,
        'encoding': encoding,
        'title': title,
        'dtype': dtype,
        'dtype2': dtype2,
        'flip': flip,
        'html_locator': html_locator,
        'info_locator': info_locator
    }


    with open('data.json', 'r') as json_file:
        data_list = json.load(json_file)

    data_list.append(data)

    with open('data.json', 'w', encoding='utf-8') as f:
        json.dump(data_list, f, ensure_ascii=False, indent=4)

# %%
url = 'http://gradschool.ustc.edu.cn/column/178'
title = '研究生院'
dtype = '培养工作'
dtype2 = '课程管理'
flip = False
encoding = None
html_locator = [
    {'method': 'find', 'args': 'div', 'kwargs': {'class_': 'r-box'}},
    {'method': 'find', 'args': 'ul'},
    {'method': 'find_all', 'args': 'li'}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': 'a', 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': 'time', 'args2': 'text'},
]

create_json(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)

# %%
url = 'http://gradschool.ustc.edu.cn/column/180'
encoding = None
title = '研究生院'
dtype = '培养工作'
dtype2 = '研究生教育国际化'
flip = False
html_locator = [
    {'method': 'find', 'args': 'div', 'kwargs': {'class_': 'r-box'}},
    {'method': 'find', 'args': 'ul'},
    {'method': 'find_all', 'args': 'li'}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': 'a', 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': 'time', 'args2': 'text'},
]

add_data(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)

# %%
url = 'https://sz.ustc.edu.cn/wdxz_list/98-1.html'
encoding = None
title = '苏州高等研究院'
dtype = '规则制度'
dtype2 = None
flip = False
html_locator = [
    {'method': 'find', 'args': 'ul', 'kwargs': {'id': 'article_list_ul'}},
    {'method': 'find_all', 'args': 'li'}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': 'a', 'args2': 'title'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': None, 'args': None, 'args2': None},
]

add_data(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)

# %%
url = 'https://iat.ustc.edu.cn/iat/x161/index.html'
encoding = 'utf-8'
title = '先进技术研究院'
dtype = '公共服务'
dtype2 = None
flip = False
html_locator = [
    {'method': 'find', 'args': 'ul', 'kwargs': {'class_': 'News-list-con-ul'}},
    {'method': 'find_all', 'args': 'li'}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': ['p',{'class_' : 'News-list-con-con-head'}], 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': ['div',{'class_' : 'News-list-con-time'}], 'args2': 'text'},
]

add_data(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)

# %%
url = 'http://sds.ustc.edu.cn/15443/list{page_num}.htm'
encoding = None
title = '大数据学院'
dtype = None
dtype2 = None
flip = True
html_locator = [
    {'method': 'find', 'args': 'ul', 'kwargs': {'class_': 'wp_article_list'}},
    {'method': 'find_all', 'args': 'li'}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': ['span',{'class_' : 'Article_Title'}], 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': ['span',{'class_' : 'Article_PublishDate'}], 'args2': 'text'},
]

create_json(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)

# %%
url = 'https://www.teach.ustc.edu.cn/category/document/doc-school-file/page/{page_num}'
encoding = None
title = '教务处'
dtype = '校教字文件'
dtype2 = None
flip = True
html_locator = [
    {'method': 'find', 'args': 'ul', 'kwargs': {'class_': 'article-list'}},
    {'method': 'find_all', 'args': 'li'}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': ['span',{'class_' : 'post'}], 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': ['span',{'class_' : 'date'}], 'args2': 'text'},
]

create_json(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)

# %%
url = 'https://sist.ustc.edu.cn/5095/list{page_num}.htm'
encoding = 'utf-8'
title = '信息科学技术学院'
dtype = '学生工作'
dtype2 = None
flip = True
html_locator = [
    {'method': 'find', 'args': 'div', 'kwargs': {'class_': 'row gy-4'}},
    {'method': 'find_all', 'args': 'div', 'kwargs': {'class_': 'col-xl-4 col-md-6'}}
]

info_locator = [
    {'info': 'title', 'method': 'find', 'args': 'h5', 'args2': 'text'},
    {'info': 'url', 'method': 'find', 'args': 'a', 'args2': 'href'},
    {'info': 'time', 'method': 'find', 'args': ['p',{'class_' : 'text-muted'}], 'args2': 'text'},
]

create_json(url, encoding, title, dtype, dtype2, flip, html_locator, info_locator)
